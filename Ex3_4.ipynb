# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejesshree/EduFlow/blob/main/Ex3_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
sheets=files.upload()
# Out:
#      <input type="file" id="files-3702bee1-2aa1-49c4-8834-76656fedabae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3702bee1-2aa1-49c4-8834-76656fedabae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dt=pd.read_csv('used_cars_data - Sheet1.csv')
# x=dt.iloc[:,:-1].values
# y=dt.iloc[:,1].values
dt.head()
# Out:
#    Mileage  Price
# 0    26.60   1.75
# 1    19.67  12.50
# 2    18.20   4.50
# 3    20.77   6.00
# 4    15.20  17.74

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=1/3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(x_test)

# %%
plt.scatter(x_train,y_train,color='blue')
plt.plot(x_train,regressor.predict(x_train),color='red')
plt.show()

# %%
plt.scatter(x_test,y_test,color='blue')
plt.plot(x_train,regressor.predict(x_train),color='red')
plt.title('price vs mileage (test set)')
plt.xlabel('Mileage(km/litre)')
plt.ylabel('price')
plt.show()

# %%
import statistics as static
import seaborn as sns

# %%
dt.mean()
# Out:
# Mileage    17.867215
# Price       8.880000
# dtype: float64

# %%
plt.boxplot(dt['Mileage'],showfliers=True,showmeans=True)

plt.show()

# %%
# Box plot with min, 25%, 50%, 75%, max explicitly shown
plt.figure(figsize=(8, 6))  # Adjust figure size for better visualization
plt.boxplot(dt['Mileage'], showfliers=True, showmeans=True) # showfliers to display outliers

plt.title('Box Plot of Mileage')
plt.ylabel('Mileage')

# Calculate and display quantiles and min/max
mileage_stats = dt['Mileage'].describe()
min_val = mileage_stats['min']
q1 = mileage_stats['25%']
median = mileage_stats['50%']
q3 = mileage_stats['75%']
max_val = mileage_stats['max']

plt.text(1.1, min_val, f'Min: {min_val:.2f}', va='center')
plt.text(1.1, q1, f'25%: {q1:.2f}', va='center')
plt.text(1.1, median, f'Median: {median:.2f}', va='center')
plt.text(1.1, q3, f'75%: {q3:.2f}', va='center')
plt.text(1.1, max_val, f'Max: {max_val:.2f}', va='center')

plt.show()

# %%
dt.describe()
# Out:
#          Mileage      Price
# count  79.000000  79.000000
# mean   17.867215   8.880000
# std     5.428686   7.718803
# min     0.000000   1.250000
# 25%    14.465000   3.725000
# 50%    17.800000   5.990000
# 75%    21.815000  11.225000
# max    28.400000  35.670000

# %%
from sklearn.metrics import mean_squared_error
slope = regressor.coef_[0]
y_intercept=regressor.intercept_
print(f"Slope: {slope}")
print(f"-intercept: {y_intercept}")
mse = mean_squared_error(y_test,y_pred)
print(f"Mean squared error: {mse}")
# Out:
# Slope: -0.6643080687823271
# -intercept: 20.79969953450577
# Mean squared error: 32.35857407803193

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files
sheet1=files.upload()
# Out:
#      <input type="file" id="files-98a3a81e-bc97-40e5-aaa8-02305cda6944" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-98a3a81e-bc97-40e5-aaa8-02305cda6944">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('car_sales_data - car_sales_data.csv')
df.head()
# Out:
#   Car Model  Price (₹ Lakhs)  Mileage (km/litre)  Sales (Units Sold)
# 0     Car 1              6.7                10.6                2443
# 1     Car 2             11.6                22.7                1127
# 2     Car 3              9.7                16.3                1086
# 3     Car 4              8.6                20.2                2148
# 4     Car 5              4.8                28.2                2491

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
x=df[['Price (₹ Lakhs)','Mileage (km/litre)'	]]
y=df['Sales (Units Sold)']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
mae = mean_absolute_error(y_test,y_pred)
mse= mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
r2=r2_score(y_test,y_pred)
print("Model Coefficient: ",model.coef_)
print("Intercept: ",model.intercept_)
print("Mean Absolute error: ",mae)
print("Mean Squared error: ",mse)
print("R2 score: ",r2)
# Out:
# Model Coefficient:  [-5.98117201  3.93876114]
# Intercept:  1417.171872744953
# Mean Absolute error:  571.4180140503303
# Mean Squared error:  428051.9060558112
# R2 score:  -0.08438066877910644

# %%
plt.figure(figsize=(8,5))
plt.scatter(y_test,y_pred,color='blue',alpha=0.6,label="Predicted vs Actual")
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color="red", linestyle="--", label="Perfect Fit")
plt.xlabel("Actual Sales")
plt.ylabel("Predicted Sales")
plt.title("Actual vs Predicted Car Sales")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Predict for a new car (example: ₹8L, 18 km/l)
new_car = [[8, 18]]
predicted_sales = model.predict(new_car)
print(f"Predicted Sales: {int(predicted_sales[0])} units")
# Out:
# Predicted Sales: 1440 units
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from google.colab import files
sheets=files.upload()
# Out:
#      <input type="file" id="files-9aee15b5-4094-4f5d-8498-58f879762b63" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9aee15b5-4094-4f5d-8498-58f879762b63">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
df1=pd.read_csv('car_sales_data.csv')
df1.head()
numerical_columns=['Price (₹ Lakhs)','Mileage (km/litre)','Sales (Units Sold)']
summary = df1[numerical_columns].describe(percentiles=[0.25, 0.5, 0.75])
summ = df1['Sales (Units Sold)'].describe(percentiles=[0.25,0.5,0.75])
print(summary)
five_no_summary=summary.loc[["min","25%","50%","75%","max"]]
plotting = summ.loc[["min","25%","50%","75%","max"]]
print(five_no_summary)
fig = plt.figure(figsize=(8,5))
plt.boxplot(plotting)
plt.show()
# Out:
#        Price (₹ Lakhs)  Mileage (km/litre)  Sales (Units Sold)
# count       100.000000          100.000000          100.000000
# mean          7.494000           19.954000         1486.800000
# std           2.529615            5.861661          577.094516
# min           3.500000           10.100000          516.000000
# 25%           5.175000           14.800000          991.000000
# 50%           7.450000           20.150000         1505.500000
# 75%           9.700000           25.300000         1943.500000
# max          11.900000           29.700000         2491.000000
#      Price (₹ Lakhs)  Mileage (km/litre)  Sales (Units Sold)
# min            3.500               10.10               516.0
# 25%            5.175               14.80               991.0
# 50%            7.450               20.15              1505.5
# 75%            9.700               25.30              1943.5
# max           11.900               29.70              2491.0

# %%
import numpy as np
import pandas as pd
from google.colab import files
sheets=files.upload()
df2=pd.read_csv('car_sales_data - car_sales_data (1).csv')
missing = pd.isnull(df2).sum()
print(missing)
# Out:
#      <input type="file" id="files-135b666b-d60b-4373-98ac-0fa8862764bb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-135b666b-d60b-4373-98ac-0fa8862764bb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# To remove the missing values

# %%
cleaned=df2.dropna()
print(cleaned)
miss=pd.isnull(cleaned).sum()
print(miss)
# Out:
#    Car Model  Price (₹ Lakhs)  Mileage (km/litre)  Sales (Units Sold)
# 1      Car 2             11.6                22.7              1127.0
# 2      Car 3              9.7                16.3              1086.0
# 3      Car 4              8.6                20.2              2148.0
# 4      Car 5              4.8                28.2              2491.0
# 5      Car 6              4.8                15.0              1943.0
# ..       ...              ...                 ...                 ...
# 94    Car 95             10.1                16.8              1106.0
# 95    Car 96              7.7                17.0              1622.0
# 96    Car 97              7.9                24.5              1199.0
# 97    Car 98              7.1                27.9              1492.0
# 99   Car 100              4.4                25.6               690.0
#
# [92 rows x 4 columns]
# Car Model             0
# Price (₹ Lakhs)       0
# Mileage (km/litre)    0
# Sales (Units Sold)    0
# ...

# %%
covarience=df1['Sales (Units Sold)'].cov(df1['Sales (Units Sold)'])
print(round(covarience, ))
correlation = df1['Sales (Units Sold)'].corr(df1['Sales (Units Sold)'])
print(correlation)
# Out:
# 333038
# 1.0
